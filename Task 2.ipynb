# %%
#1. From your products list, create a set of categories called categories_set. (If product
#names do not contain categories, create a short parallel list categories = [..] with
#matching length and use that.)

products = ["Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch", "Camera", "Printer"]
categories = ["Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics"]
categories_set = set(categories)
print("Categories set:", categories_set)
# Out:
# Categories set: {'Electronics'}

# %%
#2. Demonstrate adding a new category to the set and show that duplicates are ignored.
products = ["Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch", "Camera", "Printer"]
categories = ["Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics"]
categories_set = set(categories)
categories_set.add("Gadgets")
print("Categories set after adding 'Gadgets':", categories_set)
# Out:
# Categories set after adding 'Gadgets': {'Gadgets', 'Electronics'}

# %%
#3. Show how to check whether a category exists in the set (print a boolean result)
products = ["Laptop", "Smartphone", "Tablet", "Headphones", "Smartwatch", "Camera", "Printer","Smart watch"]
categories = ["Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics", "Electronics","Gadgets"]
categories_set = set(categories)
print("Does 'Electronics' exist in categories_set?", "Electronics" in categories_set)
print("Does 'Gadgets' exist in categories_set?", "Gadgets" in categories_set)
# Out:
# Does 'Electronics' exist in categories_set? True
# Does 'Gadgets' exist in categories_set? True
