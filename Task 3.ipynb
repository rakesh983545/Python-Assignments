# %%
#1. Create a dictionary price_dict where keys are product names and values are prices
#(integers or floats). Include at least 6 entries.
price_dict = {
    "Laptop": 999,
    "Smartphone": 699,
    "Tablet": 399.99,
    "Headphones": 149.99,
    "Smartwatch": 249.99,
    "Camera": 799.99
}
print("Price dictionary:", price_dict)
# Out:
# Price dictionary: {'Laptop': 999, 'Smartphone': 699, 'Tablet': 399.99, 'Headphones': 149.99, 'Smartwatch': 249.99, 'Camera': 799.99}

# %%
#2. Write small code blocks to:
#Add a new product with price to price_dict.
#Update the price of an existing product.
#Remove a product by name (handle the case when the product does not exist).
price_dict = {
    "Laptop": 999,
    "Smartphone": 699,
    "Tablet": 399.99,
    "Headphones": 149.99,
    "Smartwatch": 249.99,
    "Camera": 799.99
}
price_dict["Wireless Earbuds"] = 129
print("After adding 'Wireless Earbuds':", price_dict)
price_dict["Laptop"]=100
print("After updating price of 'Laptop':", price_dict)

if "Camera" in price_dict:
    del price_dict["Camera"]
    print("After removing 'Camera':", price_dict)
else:
    print("Product 'Camera' does not exist in the dictionary.")
# Out:
# After adding 'Wireless Earbuds': {'Laptop': 999, 'Smartphone': 699, 'Tablet': 399.99, 'Headphones': 149.99, 'Smartwatch': 249.99, 'Camera': 799.99, 'Wireless Earbuds': 129}
# After updating price of 'Laptop': {'Laptop': 100, 'Smartphone': 699, 'Tablet': 399.99, 'Headphones': 149.99, 'Smartwatch': 249.99, 'Camera': 799.99, 'Wireless Earbuds': 129}
# After removing 'Camera': {'Laptop': 100, 'Smartphone': 699, 'Tablet': 399.99, 'Headphones': 149.99, 'Smartwatch': 249.99, 'Wireless Earbuds': 129}

# %%
#3. Print the average price of all products (use only dictionary operations and basic arithmetic).
total_price = sum(price_dict.values())
count = len(price_dict)
average_price = total_price / count
print("Average price of all products:", average_price)
# Out:
# Average price of all products: 287.995
